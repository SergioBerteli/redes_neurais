# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('teste.keras')

# %%
print(cv2.imread(f"3_teste.png")[:,:,0].shape)
# Out:
# (28, 28)

# %%
#image = tf.keras.utils.load_img('3_teste.png')
#image = tf.image.rgb_to_grayscale(image)

image = cv2.imread(f"3_teste.png")[:,:,0]
plt.imshow(image, cmap=plt.cm.binary)
plt.show()
image = np.invert(np.array([image]))

# input_arr = tf.keras.utils.img_to_array(image)
# input_arr = np.array([input_arr])

# %%
prediction = model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
answer = np.argmax(prediction)
plt.imshow(image[0], cmap=plt.cm.binary)
plt.show()
print(f"O numero imagem acima é o {answer}")
# Out:
# O numero imagem acima é o 2

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
index = 10

# %%
image = x_test[10]
prediction = model.predict(np.array([image]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
answer = np.argmax(prediction)
plt.imshow(image, cmap=plt.cm.binary)
plt.show()
print(f"O numero retornado pela rn é {answer}. O numero real é {y_test[10]})")
# Out:
# O numero retornado pela rn é 0. O numero real é 0)
